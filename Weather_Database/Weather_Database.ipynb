# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import numpy as np
from citipy import citipy

# Import the API key.
from config import g_key
from config import weather_api_key
#6.5.2

# %%
# Create a new set of 2,000 random latitudes and longitudes.
#6.1.4
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Get the nearest city using citipy module
from citipy import citipy

# Create a list of cities
cities = []

# Get the nearest city
for coordinate in lat_lngs: 
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
  
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 749

# %%
# Perform an API call with the OpenWeatherMap.
#6.2.3
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call: Latitude and longitude, Maximum temperature, Percent humidity, Percent cloudiness, Wind speed, Weather description (for example, clouds, fog, light rain, clear sky)
#6.2.6
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list. 6.2.6
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | faanui
# Processing Record 2 of Set 1 | kavieng
# Processing Record 3 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 1 | severo-kurilsk
# Processing Record 5 of Set 1 | la ronge
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | tornio
# Processing Record 9 of Set 1 | ueda
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | amazar
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | gat
# Processing Record 18 of Set 1 | noumea
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 1 | muros
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | ina
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | port alberni
# Processing Record 33 of Set 1 | almaznyy
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | camargo
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | almazar
# Processing Record 38 of Set 1 | ponta do sol
# Processing Record 39 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 1 | nkongsamba
# Processing Record 41 of Set 1 | bambous virieux
# Processing Record 42 of Set 1 | bukit bakri
# City not found. Skipping...
# Processing Record 43 of Set 1 | bethel
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | wageningen
# Processing Record 46 of Set 1 | mayor pablo lagerenza
# Processing Record 47 of Set 1 | te anau
# Processing Record 48 of Set 1 | longford
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | port hardy
# Processing Record 1 of Set 2 | sao borja
# Processing Record 2 of Set 2 | maghama
# City not found. Skipping...
# Processing Record 3 of Set 2 | yicheng
# Processing Record 4 of Set 2 | toora-khem
# Processing Record 5 of Set 2 | ahipara
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | chochola
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | tiksi
# Processing Record 11 of Set 2 | quatre cocos
# Processing Record 12 of Set 2 | zima
# Processing Record 13 of Set 2 | kapit
# Processing Record 14 of Set 2 | tommot
# Processing Record 15 of Set 2 | san blas
# Processing Record 16 of Set 2 | linares
# Processing Record 17 of Set 2 | coihaique
# Processing Record 18 of Set 2 | san carlos
# Processing Record 19 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | cayenne
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | aksu
# Processing Record 23 of Set 2 | pouembout
# Processing Record 24 of Set 2 | kutum
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | portland
# Processing Record 28 of Set 2 | alugan
# Processing Record 29 of Set 2 | aasiaat
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | kununurra
# Processing Record 33 of Set 2 | paso de carrasco
# Processing Record 34 of Set 2 | amga
# Processing Record 35 of Set 2 | faya
# Processing Record 36 of Set 2 | cherskiy
# Processing Record 37 of Set 2 | iqaluit
# Processing Record 38 of Set 2 | kavaratti
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | longyearbyen
# Processing Record 41 of Set 2 | loukhi
# Processing Record 42 of Set 2 | ramon
# Processing Record 43 of Set 2 | fort saint james
# Processing Record 44 of Set 2 | kahului
# Processing Record 45 of Set 2 | shingu
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | saint combs
# City not found. Skipping...
# Processing Record 48 of Set 2 | omboue
# Processing Record 49 of Set 2 | talaya
# Processing Record 50 of Set 2 | fairbanks
# Processing Record 1 of Set 3 | marquette
# Processing Record 2 of Set 3 | minab
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | torbay
# Processing Record 5 of Set 3 | talara
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | bluff
# Processing Record 8 of Set 3 | beipiao
# Processing Record 9 of Set 3 | luderitz
# Processing Record 10 of Set 3 | kaitangata
# Processing Record 11 of Set 3 | atlantic city
# Processing Record 12 of Set 3 | sistranda
# Processing Record 13 of Set 3 | lavrentiya
# Processing Record 14 of Set 3 | ugoofaaru
# Processing Record 15 of Set 3 | sakakah
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | talnakh
# Processing Record 18 of Set 3 | santa rita
# Processing Record 19 of Set 3 | columbus
# Processing Record 20 of Set 3 | hualmay
# Processing Record 21 of Set 3 | mount gambier
# Processing Record 22 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 3 | eyl
# Processing Record 24 of Set 3 | ayotzingo
# City not found. Skipping...
# Processing Record 25 of Set 3 | norman wells
# Processing Record 26 of Set 3 | chuy
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 29 of Set 3 | shchelyayur
# City not found. Skipping...
# Processing Record 30 of Set 3 | mani
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | neuquen
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | bealanana
# Processing Record 35 of Set 3 | burnie
# Processing Record 36 of Set 3 | rocha
# Processing Record 37 of Set 3 | coquimbo
# Processing Record 38 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 3 | katsuura
# Processing Record 40 of Set 3 | uwayl
# City not found. Skipping...
# Processing Record 41 of Set 3 | brewster
# Processing Record 42 of Set 3 | salto de agua
# Processing Record 43 of Set 3 | tubmanburg
# Processing Record 44 of Set 3 | punta arenas
# Processing Record 45 of Set 3 | northam
# Processing Record 46 of Set 3 | luena
# Processing Record 47 of Set 3 | senmonorom
# City not found. Skipping...
# Processing Record 48 of Set 3 | firminy
# Processing Record 49 of Set 3 | aybak
# City not found. Skipping...
# Processing Record 50 of Set 3 | ahuimanu
# Processing Record 1 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 2 of Set 4 | roebourne
# Processing Record 3 of Set 4 | santander
# Processing Record 4 of Set 4 | kruisfontein
# Processing Record 5 of Set 4 | chase
# Processing Record 6 of Set 4 | mollendo
# Processing Record 7 of Set 4 | cabo san lucas
# Processing Record 8 of Set 4 | teahupoo
# Processing Record 9 of Set 4 | dunedin
# Processing Record 10 of Set 4 | ushtobe
# Processing Record 11 of Set 4 | chokurdakh
# Processing Record 12 of Set 4 | jamestown
# Processing Record 13 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 4 | sunrise manor
# Processing Record 15 of Set 4 | viedma
# Processing Record 16 of Set 4 | esperance
# Processing Record 17 of Set 4 | kaeo
# Processing Record 18 of Set 4 | rovaniemi
# Processing Record 19 of Set 4 | nikolskoye
# Processing Record 20 of Set 4 | high level
# Processing Record 21 of Set 4 | ilulissat
# Processing Record 22 of Set 4 | khatanga
# Processing Record 23 of Set 4 | sur
# Processing Record 24 of Set 4 | arraial do cabo
# Processing Record 25 of Set 4 | grindavik
# Processing Record 26 of Set 4 | springfield
# Processing Record 27 of Set 4 | nome
# Processing Record 28 of Set 4 | sao filipe
# Processing Record 29 of Set 4 | nishihara
# Processing Record 30 of Set 4 | port hedland
# Processing Record 31 of Set 4 | vila franca do campo
# Processing Record 32 of Set 4 | avera
# Processing Record 33 of Set 4 | tuy hoa
# Processing Record 34 of Set 4 | mabaruma
# Processing Record 35 of Set 4 | jiuquan
# Processing Record 36 of Set 4 | saint-philippe
# Processing Record 37 of Set 4 | udachnyy
# Processing Record 38 of Set 4 | mabamba
# Processing Record 39 of Set 4 | hamilton
# Processing Record 40 of Set 4 | georgetown
# Processing Record 41 of Set 4 | isangel
# Processing Record 42 of Set 4 | kushiro
# Processing Record 43 of Set 4 | barentu
# Processing Record 44 of Set 4 | alice springs
# Processing Record 45 of Set 4 | yellowknife
# Processing Record 46 of Set 4 | maniitsoq
# Processing Record 47 of Set 4 | puerto del rosario
# Processing Record 48 of Set 4 | bilma
# Processing Record 49 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 4 | mount isa
# Processing Record 1 of Set 5 | constitucion
# Processing Record 2 of Set 5 | oranjemund
# Processing Record 3 of Set 5 | oktyabrskiy
# Processing Record 4 of Set 5 | haines junction
# Processing Record 5 of Set 5 | lufilufi
# Processing Record 6 of Set 5 | kilgore
# Processing Record 7 of Set 5 | hasaki
# Processing Record 8 of Set 5 | ust-ordynskiy
# Processing Record 9 of Set 5 | biak
# Processing Record 10 of Set 5 | salinopolis
# Processing Record 11 of Set 5 | polson
# Processing Record 12 of Set 5 | seoul
# Processing Record 13 of Set 5 | misasi
# Processing Record 14 of Set 5 | valparaiso
# Processing Record 15 of Set 5 | pemangkat
# Processing Record 16 of Set 5 | rio grande
# Processing Record 17 of Set 5 | price
# Processing Record 18 of Set 5 | ulaangom
# Processing Record 19 of Set 5 | lugovskoy
# Processing Record 20 of Set 5 | honningsvag
# Processing Record 21 of Set 5 | policoro
# Processing Record 22 of Set 5 | sibolga
# Processing Record 23 of Set 5 | adiake
# Processing Record 24 of Set 5 | alofi
# Processing Record 25 of Set 5 | ginda
# Processing Record 26 of Set 5 | sinnamary
# Processing Record 27 of Set 5 | kodiak
# Processing Record 28 of Set 5 | williams lake
# Processing Record 29 of Set 5 | zyryanka
# Processing Record 30 of Set 5 | guerrero negro
# Processing Record 31 of Set 5 | khuzhir
# Processing Record 32 of Set 5 | klaksvik
# Processing Record 33 of Set 5 | yeletskiy
# City not found. Skipping...
# Processing Record 34 of Set 5 | walvis bay
# Processing Record 35 of Set 5 | hutchinson
# Processing Record 36 of Set 5 | zhanakorgan
# Processing Record 37 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 5 | turayf
# Processing Record 39 of Set 5 | novyy rogachik
# Processing Record 40 of Set 5 | leningradskiy
# Processing Record 41 of Set 5 | bharatpur
# Processing Record 42 of Set 5 | coahuayana
# Processing Record 43 of Set 5 | husavik
# Processing Record 44 of Set 5 | dickinson
# Processing Record 45 of Set 5 | palasa
# Processing Record 46 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 5 | verkhoyansk
# Processing Record 48 of Set 5 | trairi
# Processing Record 49 of Set 5 | carnarvon
# Processing Record 50 of Set 5 | asau
# Processing Record 1 of Set 6 | hay river
# Processing Record 2 of Set 6 | kataysk
# Processing Record 3 of Set 6 | kudahuvadhoo
# Processing Record 4 of Set 6 | malanje
# Processing Record 5 of Set 6 | teya
# Processing Record 6 of Set 6 | srednekolymsk
# Processing Record 7 of Set 6 | kamennomostskiy
# Processing Record 8 of Set 6 | namibe
# Processing Record 9 of Set 6 | yerbogachen
# Processing Record 10 of Set 6 | west bay
# Processing Record 11 of Set 6 | bud
# Processing Record 12 of Set 6 | babayurt
# Processing Record 13 of Set 6 | tasiilaq
# Processing Record 14 of Set 6 | krasnyy chikoy
# Processing Record 15 of Set 6 | ransang
# Processing Record 16 of Set 6 | champasak
# Processing Record 17 of Set 6 | pitimbu
# Processing Record 18 of Set 6 | baykit
# Processing Record 19 of Set 6 | inongo
# Processing Record 20 of Set 6 | sergeyevka
# Processing Record 21 of Set 6 | ketchikan
# Processing Record 22 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 23 of Set 6 | mareeba
# Processing Record 24 of Set 6 | stoke-on-trent
# Processing Record 25 of Set 6 | vestmanna
# Processing Record 26 of Set 6 | belyy yar
# Processing Record 27 of Set 6 | havre-saint-pierre
# Processing Record 28 of Set 6 | broken hill
# Processing Record 29 of Set 6 | sola
# Processing Record 30 of Set 6 | bambanglipuro
# Processing Record 31 of Set 6 | orel
# Processing Record 32 of Set 6 | lishu
# Processing Record 33 of Set 6 | mahebourg
# Processing Record 34 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 6 | wana
# Processing Record 36 of Set 6 | umm lajj
# Processing Record 37 of Set 6 | horconcitos
# Processing Record 38 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 6 | lompoc
# Processing Record 40 of Set 6 | xining
# Processing Record 41 of Set 6 | yulara
# Processing Record 42 of Set 6 | abu dhabi
# Processing Record 43 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 44 of Set 6 | saskylakh
# Processing Record 45 of Set 6 | bandarbeyla
# Processing Record 46 of Set 6 | bone
# Processing Record 47 of Set 6 | san isidro
# Processing Record 48 of Set 6 | campoverde
# Processing Record 49 of Set 6 | narsaq
# Processing Record 50 of Set 6 | correntina
# Processing Record 1 of Set 7 | souillac
# Processing Record 2 of Set 7 | riwaka
# Processing Record 3 of Set 7 | bakel
# Processing Record 4 of Set 7 | peleduy
# Processing Record 5 of Set 7 | demirci
# Processing Record 6 of Set 7 | beringovskiy
# Processing Record 7 of Set 7 | rongcheng
# Processing Record 8 of Set 7 | kastamonu
# Processing Record 9 of Set 7 | sterling
# Processing Record 10 of Set 7 | chute-aux-outardes
# Processing Record 11 of Set 7 | henties bay
# Processing Record 12 of Set 7 | kabarnet
# Processing Record 13 of Set 7 | challapata
# Processing Record 14 of Set 7 | grand gaube
# Processing Record 15 of Set 7 | troyes
# Processing Record 16 of Set 7 | mitu
# Processing Record 17 of Set 7 | poum
# Processing Record 18 of Set 7 | ak-dovurak
# Processing Record 19 of Set 7 | ancud
# Processing Record 20 of Set 7 | mujiayingzi
# Processing Record 21 of Set 7 | airai
# Processing Record 22 of Set 7 | sitka
# Processing Record 23 of Set 7 | kurumkan
# Processing Record 24 of Set 7 | waipawa
# Processing Record 25 of Set 7 | lagoa
# Processing Record 26 of Set 7 | yaring
# Processing Record 27 of Set 7 | tura
# Processing Record 28 of Set 7 | dubai
# Processing Record 29 of Set 7 | fortuna
# Processing Record 30 of Set 7 | san policarpo
# Processing Record 31 of Set 7 | shimoda
# Processing Record 32 of Set 7 | padang
# Processing Record 33 of Set 7 | port blair
# Processing Record 34 of Set 7 | jakhal mandi
# City not found. Skipping...
# Processing Record 35 of Set 7 | arsk
# Processing Record 36 of Set 7 | clyde river
# Processing Record 37 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 7 | lewistown
# Processing Record 39 of Set 7 | westport
# Processing Record 40 of Set 7 | berdigestyakh
# Processing Record 41 of Set 7 | waingapu
# Processing Record 42 of Set 7 | cape canaveral
# Processing Record 43 of Set 7 | paytug
# City not found. Skipping...
# Processing Record 44 of Set 7 | kihei
# Processing Record 45 of Set 7 | bayji
# Processing Record 46 of Set 7 | nanortalik
# Processing Record 47 of Set 7 | pisco
# Processing Record 48 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 49 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 50 of Set 7 | qaqortoq
# Processing Record 1 of Set 8 | iskateley
# Processing Record 2 of Set 8 | mehamn
# Processing Record 3 of Set 8 | mineiros
# Processing Record 4 of Set 8 | logrono
# Processing Record 5 of Set 8 | mayumba
# Processing Record 6 of Set 8 | santa maria
# Processing Record 7 of Set 8 | nuuk
# Processing Record 8 of Set 8 | san patricio
# Processing Record 9 of Set 8 | araouane
# Processing Record 10 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 8 | praia
# Processing Record 12 of Set 8 | bunol
# Processing Record 13 of Set 8 | changping
# Processing Record 14 of Set 8 | leh
# Processing Record 15 of Set 8 | casa nova
# Processing Record 16 of Set 8 | tamiahua
# Processing Record 17 of Set 8 | luau
# Processing Record 18 of Set 8 | manthani
# Processing Record 19 of Set 8 | asayita
# City not found. Skipping...
# Processing Record 20 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 8 | codrington
# Processing Record 22 of Set 8 | haimen
# Processing Record 23 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 8 | aripuana
# Processing Record 25 of Set 8 | broome
# Processing Record 26 of Set 8 | sisimiut
# Processing Record 27 of Set 8 | ponta delgada
# Processing Record 28 of Set 8 | kollo
# Processing Record 29 of Set 8 | qasigiannguit
# Processing Record 30 of Set 8 | imbituba
# Processing Record 31 of Set 8 | aguada de pasajeros
# Processing Record 32 of Set 8 | tevriz
# Processing Record 33 of Set 8 | cururupu
# Processing Record 34 of Set 8 | aykhal
# Processing Record 35 of Set 8 | mount pleasant
# Processing Record 36 of Set 8 | san rafael del sur
# Processing Record 37 of Set 8 | bay roberts
# Processing Record 38 of Set 8 | milingimbi
# City not found. Skipping...
# Processing Record 39 of Set 8 | inhambane
# Processing Record 40 of Set 8 | honiara
# Processing Record 41 of Set 8 | develi
# Processing Record 42 of Set 8 | botou
# Processing Record 43 of Set 8 | caravelas
# Processing Record 44 of Set 8 | krasnoselkup
# Processing Record 45 of Set 8 | mandalgovi
# Processing Record 46 of Set 8 | oistins
# Processing Record 47 of Set 8 | goderich
# Processing Record 48 of Set 8 | vigrestad
# Processing Record 49 of Set 8 | otaki
# Processing Record 50 of Set 8 | nacala
# Processing Record 1 of Set 9 | andros town
# Processing Record 2 of Set 9 | acapulco
# Processing Record 3 of Set 9 | gamba
# Processing Record 4 of Set 9 | vichy
# Processing Record 5 of Set 9 | sabancuy
# Processing Record 6 of Set 9 | eskasem
# City not found. Skipping...
# Processing Record 7 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 9 | hovd
# Processing Record 9 of Set 9 | kalabo
# Processing Record 10 of Set 9 | geraldton
# Processing Record 11 of Set 9 | qeshm
# Processing Record 12 of Set 9 | kybartai
# Processing Record 13 of Set 9 | denpasar
# Processing Record 14 of Set 9 | kraskino
# Processing Record 15 of Set 9 | pasighat
# Processing Record 16 of Set 9 | xuddur
# Processing Record 17 of Set 9 | haapiti
# Processing Record 18 of Set 9 | potchefstroom
# Processing Record 19 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 20 of Set 9 | vao
# Processing Record 21 of Set 9 | gbarnga
# Processing Record 22 of Set 9 | mfou
# Processing Record 23 of Set 9 | popondetta
# Processing Record 24 of Set 9 | port keats
# Processing Record 25 of Set 9 | karratha
# Processing Record 26 of Set 9 | san quintin
# Processing Record 27 of Set 9 | barinas
# Processing Record 28 of Set 9 | zhuhai
# Processing Record 29 of Set 9 | muttupet
# Processing Record 30 of Set 9 | sabzevar
# Processing Record 31 of Set 9 | kyaikkami
# Processing Record 32 of Set 9 | bartica
# Processing Record 33 of Set 9 | nioro
# Processing Record 34 of Set 9 | vicuna
# Processing Record 35 of Set 9 | lorengau
# Processing Record 36 of Set 9 | bengkulu
# Processing Record 37 of Set 9 | victoria
# Processing Record 38 of Set 9 | muroto
# Processing Record 39 of Set 9 | derzhavinsk
# Processing Record 40 of Set 9 | avanigadda
# Processing Record 41 of Set 9 | najran
# Processing Record 42 of Set 9 | ginir
# Processing Record 43 of Set 9 | praya
# Processing Record 44 of Set 9 | dodge city
# Processing Record 45 of Set 9 | wicklow
# Processing Record 46 of Set 9 | zhangye
# Processing Record 47 of Set 9 | canitas
# City not found. Skipping...
# Processing Record 48 of Set 9 | alto araguaia
# Processing Record 49 of Set 9 | mahibadhoo
# Processing Record 50 of Set 9 | santa fe
# Processing Record 1 of Set 10 | hobyo
# Processing Record 2 of Set 10 | paciran
# Processing Record 3 of Set 10 | vestmannaeyjar
# Processing Record 4 of Set 10 | puerto ayacucho
# Processing Record 5 of Set 10 | iacu
# Processing Record 6 of Set 10 | cidreira
# Processing Record 7 of Set 10 | durazno
# Processing Record 8 of Set 10 | imeni poliny osipenko
# Processing Record 9 of Set 10 | barra do garcas
# Processing Record 10 of Set 10 | blackwater
# Processing Record 11 of Set 10 | aklavik
# Processing Record 12 of Set 10 | mildura
# Processing Record 13 of Set 10 | champerico
# Processing Record 14 of Set 10 | guiglo
# Processing Record 15 of Set 10 | kyshtovka
# Processing Record 16 of Set 10 | ambon
# Processing Record 17 of Set 10 | axim
# Processing Record 18 of Set 10 | xapuri
# Processing Record 19 of Set 10 | komsomolskiy
# Processing Record 20 of Set 10 | soderhamn
# Processing Record 21 of Set 10 | careiro da varzea
# Processing Record 22 of Set 10 | vila
# Processing Record 23 of Set 10 | cortez
# Processing Record 24 of Set 10 | pevek
# Processing Record 25 of Set 10 | basoko
# Processing Record 26 of Set 10 | dunkwa
# Processing Record 27 of Set 10 | hami
# Processing Record 28 of Set 10 | laguna
# Processing Record 29 of Set 10 | dafeng
# Processing Record 30 of Set 10 | barraute
# Processing Record 31 of Set 10 | maputo
# Processing Record 32 of Set 10 | wainwright
# Processing Record 33 of Set 10 | yumen
# Processing Record 34 of Set 10 | bima
# Processing Record 35 of Set 10 | ekhabi
# Processing Record 36 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 10 | gazojak
# Processing Record 38 of Set 10 | rehoboth
# Processing Record 39 of Set 10 | bollnas
# Processing Record 40 of Set 10 | harper
# Processing Record 41 of Set 10 | olafsvik
# Processing Record 42 of Set 10 | kidal
# Processing Record 43 of Set 10 | autun
# Processing Record 44 of Set 10 | high rock
# Processing Record 45 of Set 10 | lishui
# Processing Record 46 of Set 10 | slave lake
# Processing Record 47 of Set 10 | hvide sande
# Processing Record 48 of Set 10 | kota kinabalu
# Processing Record 49 of Set 10 | tuatapere
# Processing Record 50 of Set 10 | neyshabur
# Processing Record 1 of Set 11 | plettenberg bay
# Processing Record 2 of Set 11 | egvekinot
# Processing Record 3 of Set 11 | richards bay
# Processing Record 4 of Set 11 | chlorakas
# Processing Record 5 of Set 11 | marawi
# Processing Record 6 of Set 11 | hambantota
# Processing Record 7 of Set 11 | pacific grove
# Processing Record 8 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 11 | seondha
# Processing Record 10 of Set 11 | santa rosa
# Processing Record 11 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 11 | de-kastri
# Processing Record 13 of Set 11 | mawlaik
# Processing Record 14 of Set 11 | zhigansk
# Processing Record 15 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 11 | bukan
# Processing Record 17 of Set 11 | zabol
# Processing Record 18 of Set 11 | tazmalt
# Processing Record 19 of Set 11 | teluk nibung
# Processing Record 20 of Set 11 | camacha
# Processing Record 21 of Set 11 | sitrah
# Processing Record 22 of Set 11 | kargasok
# Processing Record 23 of Set 11 | berzunti
# Processing Record 24 of Set 11 | oussouye
# Processing Record 25 of Set 11 | mecca
# Processing Record 26 of Set 11 | zabid
# Processing Record 27 of Set 11 | lannion
# Processing Record 28 of Set 11 | lida
# Processing Record 29 of Set 11 | necochea
# Processing Record 30 of Set 11 | mao
# Processing Record 31 of Set 11 | half moon bay
# Processing Record 32 of Set 11 | chesterville
# Processing Record 33 of Set 11 | tiruchchirappalli
# Processing Record 34 of Set 11 | yugo-kamskiy
# Processing Record 35 of Set 11 | riachao
# Processing Record 36 of Set 11 | nyurba
# Processing Record 37 of Set 11 | jagraon
# Processing Record 38 of Set 11 | otjimbingwe
# Processing Record 39 of Set 11 | pangnirtung
# Processing Record 40 of Set 11 | quzhou
# Processing Record 41 of Set 11 | nouakchott
# Processing Record 42 of Set 11 | kocevje
# Processing Record 43 of Set 11 | pontes e lacerda
# Processing Record 44 of Set 11 | ordu
# Processing Record 45 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 46 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 11 | ballina
# Processing Record 48 of Set 11 | sinop
# Processing Record 49 of Set 11 | panjab
# Processing Record 50 of Set 11 | bogovarovo
# Processing Record 1 of Set 12 | jalu
# Processing Record 2 of Set 12 | hadejia
# Processing Record 3 of Set 12 | kuito
# Processing Record 4 of Set 12 | zhenlai
# Processing Record 5 of Set 12 | sioux lookout
# Processing Record 6 of Set 12 | lovington
# Processing Record 7 of Set 12 | touros
# Processing Record 8 of Set 12 | carballo
# Processing Record 9 of Set 12 | doha
# Processing Record 10 of Set 12 | lakatoro
# Processing Record 11 of Set 12 | daru
# Processing Record 12 of Set 12 | manokwari
# Processing Record 13 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 14 of Set 12 | kampong cham
# Processing Record 15 of Set 12 | itoman
# Processing Record 16 of Set 12 | taunggyi
# Processing Record 17 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 18 of Set 12 | comodoro rivadavia
# Processing Record 19 of Set 12 | plouzane
# Processing Record 20 of Set 12 | itaqui
# Processing Record 21 of Set 12 | garm
# City not found. Skipping...
# Processing Record 22 of Set 12 | troitsko-pechorsk
# Processing Record 23 of Set 12 | palitana
# Processing Record 24 of Set 12 | piacabucu
# Processing Record 25 of Set 12 | maldonado
# Processing Record 26 of Set 12 | dutse
# Processing Record 27 of Set 12 | batie
# Processing Record 28 of Set 12 | aswan
# Processing Record 29 of Set 12 | cap malheureux
# Processing Record 30 of Set 12 | canico
# Processing Record 31 of Set 12 | malbug
# Processing Record 32 of Set 12 | san andres
# Processing Record 33 of Set 12 | soyo
# Processing Record 34 of Set 12 | acarau
# Processing Record 35 of Set 12 | moyale
# Processing Record 36 of Set 12 | buraydah
# Processing Record 37 of Set 12 | chor
# Processing Record 38 of Set 12 | ambunti
# Processing Record 39 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 40 of Set 12 | karlskoga
# Processing Record 41 of Set 12 | port hawkesbury
# Processing Record 42 of Set 12 | mackay
# Processing Record 43 of Set 12 | nabire
# Processing Record 44 of Set 12 | algiers
# Processing Record 45 of Set 12 | hofn
# Processing Record 46 of Set 12 | davila
# Processing Record 47 of Set 12 | akyab
# Processing Record 48 of Set 12 | ixtapa
# Processing Record 49 of Set 12 | qarqin
# Processing Record 50 of Set 12 | busembatia
# Processing Record 1 of Set 13 | sao miguel do araguaia
# Processing Record 2 of Set 13 | ndende
# Processing Record 3 of Set 13 | svetlyy
# Processing Record 4 of Set 13 | klyuchi
# Processing Record 5 of Set 13 | orange cove
# Processing Record 6 of Set 13 | flinders
# Processing Record 7 of Set 13 | huayucachi
# Processing Record 8 of Set 13 | san ramon
# Processing Record 9 of Set 13 | vung tau
# Processing Record 10 of Set 13 | yuzawa
# Processing Record 11 of Set 13 | ritchie
# Processing Record 12 of Set 13 | jacksonville
# Processing Record 13 of Set 13 | dryden
# Processing Record 14 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 13 | linjiang
# Processing Record 17 of Set 13 | ust-maya
# Processing Record 18 of Set 13 | acajutla
# Processing Record 19 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 20 of Set 13 | petrovsk-zabaykalskiy
# Processing Record 21 of Set 13 | burica
# City not found. Skipping...
# Processing Record 22 of Set 13 | santa cruz
# Processing Record 23 of Set 13 | goldsboro
# Processing Record 24 of Set 13 | solsvik
# City not found. Skipping...
# Processing Record 25 of Set 13 | saint-augustin
# Processing Record 26 of Set 13 | hurghada
# Processing Record 27 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 13 | ferzikovo
# Processing Record 29 of Set 13 | guebwiller
# Processing Record 30 of Set 13 | kortkeros
# Processing Record 31 of Set 13 | tongliao
# Processing Record 32 of Set 13 | nieuw nickerie
# Processing Record 33 of Set 13 | batemans bay
# Processing Record 34 of Set 13 | saint-louis
# Processing Record 35 of Set 13 | marzuq
# Processing Record 36 of Set 13 | pau brasil
# Processing Record 37 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 38 of Set 13 | caconda
# Processing Record 39 of Set 13 | stromness
# Processing Record 40 of Set 13 | labuhan
# Processing Record 41 of Set 13 | nevelsk
# Processing Record 42 of Set 13 | abu samrah
# Processing Record 43 of Set 13 | motygino
# Processing Record 44 of Set 13 | usinsk
# Processing Record 45 of Set 13 | salta
# Processing Record 46 of Set 13 | hokitika
# Processing Record 47 of Set 13 | filingue
# Processing Record 48 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 13 | lasa
# Processing Record 50 of Set 13 | khorol
# Processing Record 1 of Set 14 | leon
# Processing Record 2 of Set 14 | chamrajnagar
# Processing Record 3 of Set 14 | chunskiy
# Processing Record 4 of Set 14 | cakovec
# Processing Record 5 of Set 14 | iquique
# Processing Record 6 of Set 14 | college
# Processing Record 7 of Set 14 | baherden
# Processing Record 8 of Set 14 | dingle
# Processing Record 9 of Set 14 | tilichiki
# Processing Record 10 of Set 14 | perth
# Processing Record 11 of Set 14 | preobrazheniye
# Processing Record 12 of Set 14 | betong
# Processing Record 13 of Set 14 | port lincoln
# Processing Record 14 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 14 | dauphin
# Processing Record 16 of Set 14 | boa vista
# Processing Record 17 of Set 14 | port-gentil
# Processing Record 18 of Set 14 | kingaroy
# Processing Record 19 of Set 14 | salou
# Processing Record 20 of Set 14 | gold coast
# Processing Record 21 of Set 14 | anloga
# Processing Record 22 of Set 14 | barhi
# Processing Record 23 of Set 14 | beyneu
# Processing Record 24 of Set 14 | boshnyakovo
# Processing Record 25 of Set 14 | kyra
# Processing Record 26 of Set 14 | saldanha
# Processing Record 27 of Set 14 | atbasar
# Processing Record 28 of Set 14 | tevaitoa
# Processing Record 29 of Set 14 | conceicao do castelo
# Processing Record 30 of Set 14 | miles city
# Processing Record 31 of Set 14 | verkhnyaya inta
# Processing Record 32 of Set 14 | deputatskiy
# Processing Record 33 of Set 14 | anchorage
# Processing Record 34 of Set 14 | enshi
# Processing Record 35 of Set 14 | surt
# Processing Record 36 of Set 14 | quelimane
# Processing Record 37 of Set 14 | zlatna
# Processing Record 38 of Set 14 | rawson
# Processing Record 39 of Set 14 | suzun
# Processing Record 40 of Set 14 | benguela
# Processing Record 41 of Set 14 | nsanje
# Processing Record 42 of Set 14 | new castle
# Processing Record 43 of Set 14 | angra
# City not found. Skipping...
# Processing Record 44 of Set 14 | ixcaquixtla
# City not found. Skipping...
# Processing Record 45 of Set 14 | samarai
# Processing Record 46 of Set 14 | virginia beach
# Processing Record 47 of Set 14 | rovenki
# Processing Record 48 of Set 14 | san jeronimo
# Processing Record 49 of Set 14 | felidhoo
# City not found. Skipping...
# Processing Record 50 of Set 14 | rovinj
# Processing Record 1 of Set 15 | riyadh
# Processing Record 2 of Set 15 | mana
# Processing Record 3 of Set 15 | yingcheng
# Processing Record 4 of Set 15 | sooke
# Processing Record 5 of Set 15 | kupang
# Processing Record 6 of Set 15 | brae
# Processing Record 7 of Set 15 | saint-georges
# Processing Record 8 of Set 15 | ostrovnoy
# Processing Record 9 of Set 15 | vila velha
# Processing Record 10 of Set 15 | puerto baquerizo moreno
# Processing Record 11 of Set 15 | cartagena
# Processing Record 12 of Set 15 | skibbereen
# Processing Record 13 of Set 15 | zyuzelskiy
# Processing Record 14 of Set 15 | micomeseng
# Processing Record 15 of Set 15 | san cristobal
# Processing Record 16 of Set 15 | bushehr
# Processing Record 17 of Set 15 | aranos
# Processing Record 18 of Set 15 | morgan city
# Processing Record 19 of Set 15 | ust-uda
# Processing Record 20 of Set 15 | gouyave
# Processing Record 21 of Set 15 | zhaotong
# Processing Record 22 of Set 15 | pithoragarh
# Processing Record 23 of Set 15 | benjamin hill
# Processing Record 24 of Set 15 | hervey bay
# Processing Record 25 of Set 15 | adrar
# Processing Record 26 of Set 15 | gorom-gorom
# Processing Record 27 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 15 | dongsheng
# Processing Record 29 of Set 15 | ishigaki
# Processing Record 30 of Set 15 | bintulu
# Processing Record 31 of Set 15 | muisne
# Processing Record 32 of Set 15 | bosaso
# Processing Record 33 of Set 15 | tabas
# Processing Record 34 of Set 15 | aliverion
# City not found. Skipping...
# Processing Record 35 of Set 15 | sao domingos do prata
# Processing Record 36 of Set 15 | kudat
# Processing Record 37 of Set 15 | zhangjiakou
# Processing Record 38 of Set 15 | aden
# Processing Record 39 of Set 15 | frontera
# Processing Record 40 of Set 15 | bafra
# Processing Record 41 of Set 15 | cortegaca
# Processing Record 42 of Set 15 | sao joao da barra
# Processing Record 43 of Set 15 | chadiza
# Processing Record 44 of Set 15 | bhachau
# Processing Record 45 of Set 15 | issia
# Processing Record 46 of Set 15 | manadhoo
# Processing Record 47 of Set 15 | pervomayskiy
# Processing Record 48 of Set 15 | kungurtug
# Processing Record 49 of Set 15 | vardo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
#6.2.7
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Faanui -16.4833 -151.7500     81.50        71          11
# 1         Kavieng  -2.5744  150.7967     82.29        76          90
# 2  Severo-Kurilsk  50.6789  156.1250     35.40        92          82
# 3        La Ronge  55.1001 -105.2842     23.00        46          55
# 4        Thompson  55.7435  -97.8558     17.60        67          90
# 5    Puerto Ayora  -0.7393  -90.3518     77.00        94          44
# 6          Tornio  65.8481   24.1466     33.80        93          90
# 7            Ueda  36.4000  138.2667     73.00         4          22
# 8          Amazar  53.8580  120.8750     40.03        21          45
# 9         Rikitea -23.1203 -134.9692     77.92        78         100
#
#    Wind Speed Country       Description
# 0       13.27      PF        few clouds
# 1        7.78      PG        light rain
# 2        3.38      RU     broken clouds
# 3        4.61      CA     broken clouds
# 4       13.80      CA        light snow
# 5        4.00      EC  scattered clouds
# 6       13.80      FI              snow
# 7        3.00      JP        few clouds
# 8        6.96      RU  scattered clouds
# 9       14.05      PF        light rain

# %%
# Export the DataFrame as a CSV file and save it as WeatherPy_Database.csv
#6.2.7
# Create the output File (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
